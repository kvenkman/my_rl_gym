# %% [markdown]
# <a href="https://colab.research.google.com/github/kvenkman/my_rl_gym/blob/master/LunarLander-v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install box2d-py --user
# Out:
# Requirement already satisfied: box2d-py in /root/.local/lib/python3.6/site-packages (2.3.8)

# %%
# Imports
from collections import deque
import random
import numpy as np
import gym
import os
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
# DQN Agent Class
class Agent():
    def __init__(self, env):
        self.env = env
        self.epsilon = 1.0
        self.epsilon_decay = 0.995
        self.gamma = 0.99
        self.batch_size = 32
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.alpha = 0.05
        self.memory = deque(maxlen=10000)

        self.train = True # Easy way switch train/test

        # Qnetwork and target network
        self.qnetwork = self.defineNetwork()
        self.target = self.defineNetwork()
        self.alignTarget()


    def defineNetwork(self):
        model = Sequential()
        model.add(Dense(32, input_dim = self.env.observation_space.shape[0], activation="relu"))  # input layer
        model.add(Dense(32, activation="relu")) # hidden layer
        model.add(Dense(self.env.action_space.n, activation='linear')) # output layer
        model.compile(loss='mse',optimizer=Adam(lr=self.alpha))
        return model

    def alignTarget(self):
        self.target.set_weights(self.qnetwork.get_weights())

    def setSimParameters(self, episodes=100, ntimesteps=1000):
        self.episodes = episodes
        self.ntimesteps = ntimesteps

    def loadModel(self, qnetwork_path, target_path):
        self.qnetwork = load_model(qnetwork_path)
        self.target = load_model(target_path)

    def selectAction(self, state):
        if(random.uniform(0, 1) < self.epsilon):
            return env.action_space.sample()
        return np.argmax(self.qnetwork.predict(np.array(state)))

    def addToMemory(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def optimize(self): # , state, action, reward, next_state, done
        if (self.train and (len(self.memory) > self.batch_size)):
            batch = np.array(random.sample(self.memory, self.batch_size))

            train_states = []
            target_rewards = []

            for state, action, reward, next_state, done in batch:
                target = self.qnetwork.predict(state)
                if (done):
                    target[0][action] = reward
                else:
                    t = self.target.predict(next_state)
                    target[0][action] = reward + self.gamma*np.amax(t)

                train_states.append(state)
                target_rewards.append(target)

            self.qnetwork.fit(np.squeeze(train_states), np.squeeze(target_rewards), epochs = 1, verbose = 0)

    def updateEpsilon(self):
        self.epsilon *= self.epsilon_decay

# %%
# Initialize environment, agent, sim parameters
env_name = "LunarLander-v2"
env = gym.make(env_name)
myLander = Agent(env)

# Define simulation length
myLander.setSimParameters(episodes = 1000, ntimesteps = 2000)
# Out:
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
# To test lander
# myLander.train = False
# myLander.epsilon = 0
# myLander.loadModel("pickled_lander_qnetwork.h5", "pickled_lander_target.h5")

# %%
# Run simulation
for i in range(myLander.episodes): # myLander.episodes
    state = env.reset()
    print("Current episode number: ", i, myLander.ntimesteps)
    current_reward = [0]
    for _ in range(myLander.ntimesteps): # myLander.ntimesteps
        if not myLander.train:
            env.render()

        action = myLander.selectAction(state.reshape(1, 8))
        new_state, reward, done, _ = env.step(action)

        current_reward.append(reward)

        myLander.addToMemory(state.reshape(1, 8), action, reward, new_state.reshape(1, 8), done)
        myLander.optimize()

        state = new_state

        if (done):
            break

    myLander.updateEpsilon()
    myLander.alignTarget()

    if((i % 50) == 0):
        myLander.qnetwork.save("pickled_lander_qnetwork.h5")
        myLander.target.save("pickled_lander_target.h5")
        # os.system("git add pickled_lander_*.h5")
        # os.system("git commit -m \"autoupdate saved lunar lander network weights\"")
# Out:
# Current episode number:  0 2000
# Current episode number:  1 2000
# Current episode number:  2 2000
# Current episode number:  3 2000
# Current episode number:  4 2000
# Current episode number:  5 2000
# Current episode number:  6 2000
# Current episode number:  7 2000
# Current episode number:  8 2000
# Current episode number:  9 2000
# Current episode number:  10 2000
# Current episode number:  11 2000
# Current episode number:  12 2000
# Current episode number:  13 2000
# Current episode number:  14 2000
# Current episode number:  15 2000
# Current episode number:  16 2000
# Current episode number:  17 2000
# Current episode number:  18 2000
# Current episode number:  19 2000
# Current episode number:  20 2000
# Current episode number:  21 2000
# Current episode number:  22 2000
# Current episode number:  23 2000
# Current episode number:  24 2000
# Current episode number:  25 2000
# Current episode number:  26 2000
# Current episode number:  27 2000
# Current episode number:  28 2000
# Current episode number:  29 2000
# Current episode number:  30 2000
# Current episode number:  31 2000
# Current episode number:  32 2000
# Current episode number:  33 2000
# Current episode number:  34 2000
# Current episode number:  35 2000
# Current episode number:  36 2000
# Current episode number:  37 2000
# Current episode number:  38 2000
# Current episode number:  39 2000
# Current episode number:  40 2000
# Current episode number:  41 2000
# Current episode number:  42 2000
# Current episode number:  43 2000
# Current episode number:  44 2000
# Current episode number:  45 2000
# Current episode number:  46 2000
# Current episode number:  47 2000
# Current episode number:  48 2000
# Current episode number:  49 2000
# Current episode number:  50 2000
# Current episode number:  51 2000
# Current episode number:  52 2000
# Current episode number:  53 2000
# Current episode number:  54 2000
# Current episode number:  55 2000
# Current episode number:  56 2000
# Current episode number:  57 2000
# Current episode number:  58 2000
# Current episode number:  59 2000
# Current episode number:  60 2000
# Current episode number:  61 2000
# Current episode number:  62 2000
# Current episode number:  63 2000
# Current episode number:  64 2000
# Current episode number:  65 2000
# Current episode number:  66 2000
# Current episode number:  67 2000
# Current episode number:  68 2000
# Current episode number:  69 2000
# Current episode number:  70 2000
# Current episode number:  71 2000
# Current episode number:  72 2000
# Current episode number:  73 2000
# Current episode number:  74 2000
# Current episode number:  75 2000
# Current episode number:  76 2000
# Current episode number:  77 2000
# Current episode number:  78 2000
# Current episode number:  79 2000
# Current episode number:  80 2000
# Current episode number:  81 2000
# Current episode number:  82 2000
# Current episode number:  83 2000
# Current episode number:  84 2000
# Current episode number:  85 2000
# Current episode number:  86 2000
# Current episode number:  87 2000
# Current episode number:  88 2000
# Current episode number:  89 2000
# Current episode number:  90 2000
# Current episode number:  91 2000
# Current episode number:  92 2000
# Current episode number:  93 2000
# Current episode number:  94 2000
# Current episode number:  95 2000
# Current episode number:  96 2000
# Current episode number:  97 2000
# Current episode number:  98 2000
# Current episode number:  99 2000
# Current episode number:  100 2000
# Current episode number:  101 2000
# Current episode number:  102 2000
# Current episode number:  103 2000
# Current episode number:  104 2000
# Current episode number:  105 2000
# Current episode number:  106 2000
# Current episode number:  107 2000
# Current episode number:  108 2000
# Current episode number:  109 2000
# Current episode number:  110 2000
# Current episode number:  111 2000
# Current episode number:  112 2000
# Current episode number:  113 2000
# Current episode number:  114 2000
# Current episode number:  115 2000
# Current episode number:  116 2000
# Current episode number:  117 2000
# Current episode number:  118 2000
# Current episode number:  119 2000
# Current episode number:  120 2000
# Current episode number:  121 2000
# Current episode number:  122 2000
# Current episode number:  123 2000
# Current episode number:  124 2000
# Current episode number:  125 2000
# Current episode number:  126 2000
# Current episode number:  127 2000
# Current episode number:  128 2000
# Current episode number:  129 2000
# Current episode number:  130 2000
# Current episode number:  131 2000
# Current episode number:  132 2000
# Current episode number:  133 2000
# Current episode number:  134 2000
# Current episode number:  135 2000
# Current episode number:  136 2000
# Current episode number:  137 2000
# Current episode number:  138 2000
# Current episode number:  139 2000
# Current episode number:  140 2000
# Current episode number:  141 2000
# Current episode number:  142 2000
# Current episode number:  143 2000
# Current episode number:  144 2000
# Current episode number:  145 2000
# Current episode number:  146 2000
# Current episode number:  147 2000
# Current episode number:  148 2000
# Current episode number:  149 2000
# Current episode number:  150 2000
# Current episode number:  151 2000
# Current episode number:  152 2000
# Current episode number:  153 2000
# Current episode number:  154 2000
# Current episode number:  155 2000
# Current episode number:  156 2000
# Current episode number:  157 2000
# Current episode number:  158 2000
# Current episode number:  159 2000
# Current episode number:  160 2000
# Current episode number:  161 2000
# Current episode number:  162 2000
# Current episode number:  163 2000
# Current episode number:  164 2000
# Current episode number:  165 2000
# Current episode number:  166 2000
# Current episode number:  167 2000
# Current episode number:  168 2000
# Current episode number:  169 2000
# Current episode number:  170 2000
# Current episode number:  171 2000
# Current episode number:  172 2000
# Current episode number:  173 2000
# Current episode number:  174 2000
# Current episode number:  175 2000
# Current episode number:  176 2000
# Current episode number:  177 2000
# Current episode number:  178 2000
# Current episode number:  179 2000
# Current episode number:  180 2000
# Current episode number:  181 2000
# Current episode number:  182 2000
# Current episode number:  183 2000
# Current episode number:  184 2000
# Current episode number:  185 2000
# Current episode number:  186 2000
# Current episode number:  187 2000
# Current episode number:  188 2000
# Current episode number:  189 2000
# Current episode number:  190 2000
# Current episode number:  191 2000
# Current episode number:  192 2000
# Current episode number:  193 2000
# Current episode number:  194 2000
# Current episode number:  195 2000
# Current episode number:  196 2000
# Current episode number:  197 2000
# Current episode number:  198 2000
# Current episode number:  199 2000
# Current episode number:  200 2000
# Current episode number:  201 2000
# Current episode number:  202 2000
# Current episode number:  203 2000
# Current episode number:  204 2000
# Current episode number:  205 2000
# Current episode number:  206 2000
# Current episode number:  207 2000
# Current episode number:  208 2000
# Current episode number:  209 2000
# Current episode number:  210 2000
# Current episode number:  211 2000
# Current episode number:  212 2000
# Current episode number:  213 2000
# Current episode number:  214 2000
# Current episode number:  215 2000
# Current episode number:  216 2000
# Current episode number:  217 2000
# Current episode number:  218 2000
# Current episode number:  219 2000
# Current episode number:  220 2000
# Current episode number:  221 2000
# Current episode number:  222 2000
# Current episode number:  223 2000
# Current episode number:  224 2000
# Current episode number:  225 2000
# Current episode number:  226 2000
# Current episode number:  227 2000
# Current episode number:  228 2000
# Current episode number:  229 2000
# Current episode number:  230 2000
# Current episode number:  231 2000
# Current episode number:  232 2000
# Current episode number:  233 2000
# Current episode number:  234 2000
# Current episode number:  235 2000
# Current episode number:  236 2000
# Current episode number:  237 2000
# Current episode number:  238 2000
# Current episode number:  239 2000
# Current episode number:  240 2000
# Current episode number:  241 2000
# Current episode number:  242 2000
# Current episode number:  243 2000
# Current episode number:  244 2000
# Current episode number:  245 2000
# Current episode number:  246 2000
# Current episode number:  247 2000
# Current episode number:  248 2000
# Current episode number:  249 2000
# Current episode number:  250 2000
# Current episode number:  251 2000
# Current episode number:  252 2000
# Current episode number:  253 2000
# Current episode number:  254 2000
# Current episode number:  255 2000
# Current episode number:  256 2000
# Current episode number:  257 2000
# Current episode number:  258 2000
# Current episode number:  259 2000
# Current episode number:  260 2000
# Current episode number:  261 2000
# Current episode number:  262 2000
# Current episode number:  263 2000
# Current episode number:  264 2000
# Current episode number:  265 2000
# Current episode number:  266 2000
# Current episode number:  267 2000
# Current episode number:  268 2000
# Current episode number:  269 2000
# Current episode number:  270 2000
# Current episode number:  271 2000
# Current episode number:  272 2000
# Current episode number:  273 2000
# Current episode number:  274 2000
# Current episode number:  275 2000
# Current episode number:  276 2000
# Current episode number:  277 2000
# Current episode number:  278 2000
# Current episode number:  279 2000
# Current episode number:  280 2000
# Current episode number:  281 2000
# Current episode number:  282 2000
# Current episode number:  283 2000
# Current episode number:  284 2000
# Current episode number:  285 2000
# Current episode number:  286 2000
# Current episode number:  287 2000
# Current episode number:  288 2000
# Current episode number:  289 2000
# Current episode number:  290 2000
# Current episode number:  291 2000
# Current episode number:  292 2000
# Current episode number:  293 2000
# Current episode number:  294 2000
# Current episode number:  295 2000
# Current episode number:  296 2000
# Current episode number:  297 2000
# Current episode number:  298 2000
# Current episode number:  299 2000
# Current episode number:  300 2000
# Current episode number:  301 2000
# Current episode number:  302 2000
# Current episode number:  303 2000
# Current episode number:  304 2000
# Current episode number:  305 2000
# Current episode number:  306 2000
# Current episode number:  307 2000
# Current episode number:  308 2000
# Current episode number:  309 2000
# Current episode number:  310 2000
# Current episode number:  311 2000
# Current episode number:  312 2000
# Current episode number:  313 2000
# Current episode number:  314 2000
# Current episode number:  315 2000
# Current episode number:  316 2000
# Current episode number:  317 2000
# Current episode number:  318 2000
# Current episode number:  319 2000
# Current episode number:  320 2000
# Current episode number:  321 2000
# Current episode number:  322 2000
# Current episode number:  323 2000
# Current episode number:  324 2000
# Current episode number:  325 2000
# Current episode number:  326 2000
# Current episode number:  327 2000
# Current episode number:  328 2000
# Current episode number:  329 2000
# Current episode number:  330 2000
# Current episode number:  331 2000
# Current episode number:  332 2000
# Current episode number:  333 2000
# Current episode number:  334 2000
# Current episode number:  335 2000
# Current episode number:  336 2000
# Current episode number:  337 2000
# Current episode number:  338 2000
# Current episode number:  339 2000
# Current episode number:  340 2000
# Current episode number:  341 2000
# Current episode number:  342 2000
# Current episode number:  343 2000
# Current episode number:  344 2000
# Current episode number:  345 2000
# Current episode number:  346 2000
# Current episode number:  347 2000
# Current episode number:  348 2000
# Current episode number:  349 2000
# Current episode number:  350 2000
# Current episode number:  351 2000
# Current episode number:  352 2000
# Current episode number:  353 2000
# Current episode number:  354 2000
# Current episode number:  355 2000
# Current episode number:  356 2000
# Current episode number:  357 2000
# Current episode number:  358 2000
# Current episode number:  359 2000
# Current episode number:  360 2000
# Current episode number:  361 2000
# Current episode number:  362 2000
# Current episode number:  363 2000
# Current episode number:  364 2000
# Current episode number:  365 2000
# Current episode number:  366 2000
# Current episode number:  367 2000
# Current episode number:  368 2000
# Current episode number:  369 2000
# Current episode number:  370 2000
# Current episode number:  371 2000
# Current episode number:  372 2000
# Current episode number:  373 2000
# Current episode number:  374 2000
# Current episode number:  375 2000
# Current episode number:  376 2000
# Current episode number:  377 2000
# Current episode number:  378 2000
# Current episode number:  379 2000
# Current episode number:  380 2000
# Current episode number:  381 2000
# Current episode number:  382 2000
# Current episode number:  383 2000
# Current episode number:  384 2000
# Current episode number:  385 2000
# Current episode number:  386 2000
# Current episode number:  387 2000
# Current episode number:  388 2000
# Current episode number:  389 2000
# Current episode number:  390 2000
# Current episode number:  391 2000
# Current episode number:  392 2000
# Current episode number:  393 2000
# Current episode number:  394 2000
# Current episode number:  395 2000
# Current episode number:  396 2000
# Current episode number:  397 2000
# Current episode number:  398 2000
# Current episode number:  399 2000
# Current episode number:  400 2000
# Current episode number:  401 2000
# Current episode number:  402 2000
# Current episode number:  403 2000
# Current episode number:  404 2000
# Current episode number:  405 2000
# Current episode number:  406 2000
# Current episode number:  407 2000
# Current episode number:  408 2000
# Current episode number:  409 2000
# Current episode number:  410 2000
# Current episode number:  411 2000
# Current episode number:  412 2000
# Current episode number:  413 2000
# Current episode number:  414 2000
# Current episode number:  415 2000
# Current episode number:  416 2000
# Current episode number:  417 2000
# Current episode number:  418 2000
# Current episode number:  419 2000
# Current episode number:  420 2000
# Current episode number:  421 2000
# Current episode number:  422 2000
# Current episode number:  423 2000
# Current episode number:  424 2000
# Current episode number:  425 2000
# Current episode number:  426 2000
# Current episode number:  427 2000
# Current episode number:  428 2000
# Current episode number:  429 2000
# Current episode number:  430 2000
# Current episode number:  431 2000
# Current episode number:  432 2000
# Current episode number:  433 2000
# Current episode number:  434 2000
# Current episode number:  435 2000
# Current episode number:  436 2000
# Current episode number:  437 2000
# Current episode number:  438 2000
# Current episode number:  439 2000
# Current episode number:  440 2000
# Current episode number:  441 2000
# Current episode number:  442 2000
# Current episode number:  443 2000
# Current episode number:  444 2000
# Current episode number:  445 2000
# Current episode number:  446 2000
# Current episode number:  447 2000
# Current episode number:  448 2000
# Current episode number:  449 2000
# Current episode number:  450 2000
# Current episode number:  451 2000
# Current episode number:  452 2000
# Current episode number:  453 2000
# Current episode number:  454 2000
# Current episode number:  455 2000
# Current episode number:  456 2000
# Current episode number:  457 2000
# Current episode number:  458 2000
# Current episode number:  459 2000
# Current episode number:  460 2000
# Current episode number:  461 2000
# Current episode number:  462 2000
# Current episode number:  463 2000
# Current episode number:  464 2000
# Current episode number:  465 2000
# Current episode number:  466 2000
# Current episode number:  467 2000
# Current episode number:  468 2000
# Current episode number:  469 2000
# Current episode number:  470 2000
# Current episode number:  471 2000
# Current episode number:  472 2000
# Current episode number:  473 2000
# Current episode number:  474 2000
# Current episode number:  475 2000
# Current episode number:  476 2000
# Current episode number:  477 2000
# Current episode number:  478 2000
# Current episode number:  479 2000
# Current episode number:  480 2000
# Current episode number:  481 2000
# Current episode number:  482 2000
# Current episode number:  483 2000
# Current episode number:  484 2000
# Current episode number:  485 2000
# Current episode number:  486 2000
# Current episode number:  487 2000
# Current episode number:  488 2000
# Current episode number:  489 2000
# Current episode number:  490 2000
# Current episode number:  491 2000
# Current episode number:  492 2000
# Current episode number:  493 2000
# Current episode number:  494 2000
# Current episode number:  495 2000
# Current episode number:  496 2000
# Current episode number:  497 2000
# Current episode number:  498 2000
# Current episode number:  499 2000
# Current episode number:  500 2000
# Current episode number:  501 2000
# Current episode number:  502 2000
# Current episode number:  503 2000
# Current episode number:  504 2000
# Current episode number:  505 2000
# Current episode number:  506 2000
# Current episode number:  507 2000
# Current episode number:  508 2000
# Current episode number:  509 2000
# Current episode number:  510 2000
# Current episode number:  511 2000
# Current episode number:  512 2000
# Current episode number:  513 2000
# Current episode number:  514 2000
# Current episode number:  515 2000
# Current episode number:  516 2000
# Current episode number:  517 2000
# Current episode number:  518 2000
# Current episode number:  519 2000
# Current episode number:  520 2000
# Current episode number:  521 2000
# Current episode number:  522 2000
# Current episode number:  523 2000
# Current episode number:  524 2000
# Current episode number:  525 2000
# Current episode number:  526 2000
# Current episode number:  527 2000
# Current episode number:  528 2000
# Current episode number:  529 2000
# Current episode number:  530 2000
# Current episode number:  531 2000
# Current episode number:  532 2000
# Current episode number:  533 2000
# Current episode number:  534 2000
# Current episode number:  535 2000
# Current episode number:  536 2000
# Current episode number:  537 2000
# Current episode number:  538 2000
# Current episode number:  539 2000
# Current episode number:  540 2000
# Current episode number:  541 2000
# Current episode number:  542 2000
# Current episode number:  543 2000
# Current episode number:  544 2000
# Current episode number:  545 2000
# Current episode number:  546 2000
# Current episode number:  547 2000
# Current episode number:  548 2000
# Current episode number:  549 2000
# Current episode number:  550 2000
# Current episode number:  551 2000
# Current episode number:  552 2000
# Current episode number:  553 2000
# Current episode number:  554 2000
# Current episode number:  555 2000
# Current episode number:  556 2000
# Current episode number:  557 2000
# Current episode number:  558 2000
# Current episode number:  559 2000
# Current episode number:  560 2000
# Current episode number:  561 2000
# Current episode number:  562 2000
# Current episode number:  563 2000
# Current episode number:  564 2000
# Current episode number:  565 2000
# Current episode number:  566 2000
# Current episode number:  567 2000
# Current episode number:  568 2000
# Current episode number:  569 2000
# Current episode number:  570 2000
# Current episode number:  571 2000
# Current episode number:  572 2000
# Current episode number:  573 2000
# Current episode number:  574 2000
# Current episode number:  575 2000
# Current episode number:  576 2000
# Current episode number:  577 2000
# Current episode number:  578 2000
# Current episode number:  579 2000
# Current episode number:  580 2000
# Current episode number:  581 2000
# Current episode number:  582 2000
# Current episode number:  583 2000
# Current episode number:  584 2000
# Current episode number:  585 2000
# Current episode number:  586 2000
# Current episode number:  587 2000
# Current episode number:  588 2000
# Current episode number:  589 2000
# Current episode number:  590 2000
# Current episode number:  591 2000
# Current episode number:  592 2000
# Current episode number:  593 2000
# Current episode number:  594 2000
# Current episode number:  595 2000
# Current episode number:  596 2000
# Current episode number:  597 2000
# Current episode number:  598 2000
# Current episode number:  599 2000
# Current episode number:  600 2000
# Current episode number:  601 2000
# Current episode number:  602 2000
# Current episode number:  603 2000
# Current episode number:  604 2000
# Current episode number:  605 2000
# Current episode number:  606 2000
# Current episode number:  607 2000
# Current episode number:  608 2000
# Current episode number:  609 2000
# Current episode number:  610 2000
# Current episode number:  611 2000
# Current episode number:  612 2000
# Current episode number:  613 2000
# Current episode number:  614 2000
# Current episode number:  615 2000
# Current episode number:  616 2000
# Current episode number:  617 2000
# Current episode number:  618 2000
# Current episode number:  619 2000
# Current episode number:  620 2000
# Current episode number:  621 2000
# Current episode number:  622 2000
# Current episode number:  623 2000
# Current episode number:  624 2000
# Current episode number:  625 2000
# Current episode number:  626 2000
# Current episode number:  627 2000
# Current episode number:  628 2000
# Current episode number:  629 2000
# Current episode number:  630 2000
# Current episode number:  631 2000
# Current episode number:  632 2000
# Current episode number:  633 2000
# Current episode number:  634 2000
# Current episode number:  635 2000
# Current episode number:  636 2000
# Current episode number:  637 2000
# Current episode number:  638 2000
# Current episode number:  639 2000
# Current episode number:  640 2000
# Current episode number:  641 2000
# Current episode number:  642 2000
# Current episode number:  643 2000
# Current episode number:  644 2000
# Current episode number:  645 2000
# Current episode number:  646 2000
# Current episode number:  647 2000
# Current episode number:  648 2000
# Current episode number:  649 2000
# Current episode number:  650 2000
# Current episode number:  651 2000
# Current episode number:  652 2000
# Current episode number:  653 2000
# Current episode number:  654 2000
# Current episode number:  655 2000
# Current episode number:  656 2000
# Current episode number:  657 2000
# Current episode number:  658 2000
# Current episode number:  659 2000
# Current episode number:  660 2000
# Current episode number:  661 2000
# Current episode number:  662 2000
# Current episode number:  663 2000
# Current episode number:  664 2000
# Current episode number:  665 2000
# Current episode number:  666 2000
# Current episode number:  667 2000
# Current episode number:  668 2000
# Current episode number:  669 2000
# Current episode number:  670 2000
# Current episode number:  671 2000
# Current episode number:  672 2000
# Current episode number:  673 2000
# Current episode number:  674 2000
# Current episode number:  675 2000

# %%
plt.figure(figsize=(12,6))
plt.plot(current_reward)
plt.title("Rewards vs Episode #", size=15)
plt.xlabel("Episode #", size=12)
plt.ylabel("Rewards", size=12)
plt.grid()
plt.savefig("rewards.png")

# %%
myLander.qnetwork.save("pickled_lander_qnetwork.h5")
myLander.target.save("pickled_lander_target.h5")
